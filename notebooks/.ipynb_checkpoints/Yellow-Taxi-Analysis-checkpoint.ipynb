# %%
import pandas
import sqlalchemy

engine = sqlalchemy.create_engine('postgresql+psycopg2://postgres:postgres123@localhost/nycdata')

# %%
query = '''
SELECT 
	tpep_pickup_datetime::DATE as pickup_day,
	total_amount
FROM 
	public.yellow_taxis
WHERE
    tpep_pickup_datetime::DATE BETWEEN '2023-12-01' AND '2023-12-31'
order by
    1 asc
'''


df = pandas.read_sql_query(query, con=engine)
df
# Out:
#          pickup_day  total_amount
# 0        2023-12-01         21.50
# 1        2023-12-01         12.20
# 2        2023-12-01         18.40
# 3        2023-12-01         32.70
# 4        2023-12-01         11.80
# ...             ...           ...
# 3154066  2023-12-31         16.35
# 3154067  2023-12-31         22.65
# 3154068  2023-12-31         19.32
# 3154069  2023-12-31         18.90
# 3154070  2023-12-31         23.66
#
# [3154071 rows x 2 columns]

# %%
plot_data = df.groupby('pickup_day')['total_amount'].sum()

import matplotlib
chart = plot_data.plot(xlabel="Pickup Day", ylabel="Total Amount", kind='line', legend=True, figsize=(12, 8))

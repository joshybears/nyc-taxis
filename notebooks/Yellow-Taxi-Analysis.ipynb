# %%
import pandas
import sqlalchemy

engine = sqlalchemy.create_engine('postgresql+psycopg2://postgres:postgres123@localhost/nycdata')

# %%
query = '''
SELECT 
	tpep_pickup_datetime::DATE as pickup_day,
	total_amount
FROM 
	public.yellow_taxis
'''


df = pandas.read_sql_query(query, con=engine)
df
# Out:
#          pickup_day  total_amount
# 0        2023-12-01         21.50
# 1        2023-12-01         12.20
# 2        2023-12-01         18.40
# 3        2023-12-01         32.70
# 4        2023-12-01         11.80
# ...             ...           ...
# 5943970  2023-02-28         18.00
# 5943971  2023-02-28         18.84
# 5943972  2023-02-28         25.56
# 5943973  2023-02-28         48.85
# 5943974  2023-02-28         32.28
#
# [5943975 rows x 2 columns]

# %%
groups = df.groupby('pickup_day')

import matplotlib
chart = groups.total_amount.plot(xlabel="Sample", ylabel="Date", kind='line', legend=True, marker='o', linestyle='dashed')
